# %% [markdown]
# <a href="https://colab.research.google.com/github/ProffesorXavier/Zafar/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print('Привет Мир!')
# print ('Меня зовут Зафар')
# print ('Мне 30 лет')
# text='Моя первая переменная!'
# print(text)
# second='И не последняя!'
# print(second)

# name='Иван'
# print('Меня зовут')
# print(name)
# print('Мой любимый цвет:')
# print('Зеленый')
# print('Мой любимый вид спорта:')
# print('Бег')

# first = ('Моя первая переменная!')
# print(first)
# second = ('И не последняя!')
# print(second)

# my_color = ('Зелёный')
# sport = ('Бег')
# print('Меня зовут')
# name = 'Иван'
# print(name)
# print('Мой любимый цвет:')
# print(my_color)
# print('Мой любимый вид спорта:')
# print(sport)

# my_color = ('Зелёный')
# sport = ('Бег')
# print('Меня зовут')
# name = 'Иван'
# print(name)
# print('Мой любимый цвет:')
# print(my_color)
# print('Мой любимый вид спорта:')
# print(sport)

# sur_name = input('Введите фамилию: ')
# print('Ваша фамилия —', sur_name)

# name = input("Введите имя: ")
# print ("Привет, " + name + '!')

# вывод инпутов и склеивание их в ряд
# first_word = input("Введите первое слово: ")
# second_word = input("Введите второе слово: ")
# print(first_word + (' ') + second_word)

# написание переменных в ряд
# name1, name2, name3 = 'Иван', 'Петр', 'Сергей'
# print(name1, name2, name3)

# client = 'Петя '
# pet = ' кот '
# print(client + 'и' + pet)

# r = 'Red'
# g = 'Green'
# b = 'Blue'

# print(r, b, g, r+g+b, b, g+b)

# first_animal = ("Заяц")
# second_animal = ("Черепаха")
# print (first_animal, "спит", second_animal, "идёт")

# first_name = input('Введите имя пользователя: ')
# greeting = 'Привет, '
# print(greeting, first_name)
# intro = "К сожалению, у Вас нет доступа к системе."
# info = "Пожалуйста, обратитесь к системному администратору."
# print(intro)
# print (info)

# departure_city = input("Введите город вылета: ")
# arrival_city = input("Введите город прилёта: ")
# print (departure_city, " - " ,arrival_city)

# a = input('Введите первое слово: ')
# b = input('Введите второе слово: ')
# print(a, b)
# print(b, a)

# a = input('Введите первое слово: ')
# b = input('Введите второе слово: ')
# print(a,b)
# a,b = b,a
# print(a,b)

# print (6*39, 3**5, -8/-4, 10/2+6)

# x = int(input('Введите 1 число: '))
# y = int(input('Введите 2 число: '))
# c = ("Сумма: ")
# print (c, x+y)

#
# a = '2'
# b = '5'
# c = '3'
# num = 6 ** int(a) + (7 - int(b)) * int(c)
# print(num)

# Деление нацело
# apples = 41
# boxes = 3
# print("Полных ящиков: ", apples//boxes)
# print("Осталось: ", apples%boxes)

# user_number = int(input("Введите число: "))
# home_number = int(input("Введите номер дома: "))
# apartment_number = int(input("Введите номер квартиры: "))
# print ("Номер дома: ", user_number % 10)
# print ("Номер квартиры:", user_number // 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3757935486.py in <cell line: 0>()
#     112 # print("Осталось: ", apples%boxes)
#     113
# --> 114 user_number = int(input("Введите число: "))
#     115 # home_number = int(input("Введите номер дома: "))
#     116 # apartment_number = int(input("Введите номер квартиры: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
